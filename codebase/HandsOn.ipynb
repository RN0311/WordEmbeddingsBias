# %%
import pandas as pd

df = pd.read_csv('chipotle.tsv', sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %% [markdown]
# ##### Convert into float values

# %%
df.item_price.dtype
# Out:
# dtype('O')

# %%
df.item_price = df.item_price[0:]

# %%
df.item_name.mode()
# Out:
# 0    Chicken Bowl
# dtype: object

# %%
df.order_id.mode()
# Out:
# 0    926
# dtype: int64

# %%
df.quantity.count()
# Out:
# 4622

# %%
df["item_price"] = df["item_price"].replace(["\$", ','],"", regex=True).astype(float)

# %%
df['item_price'].dtype
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df.choice_description.mode()
# Out:
# 0    [Diet Coke]
# dtype: object

# %%
revenue_generated = 0

# %%
revenue_generated = df['quantity'] * df['item_price'].groupby(df['order_id'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-18c0431264f5> in <module>
# ----> 1 revenue_generated = df['quantity'] * df['item_price'].groupby(df['order_id'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1581             rvalues = rvalues.values
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#    1585                                 index=left.index, name=res_name, dtype=None)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1527         try:
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#    1531             if is_object_dtype(lvalues):
#
# ...

# %%
revenue_generated

# %% [markdown]
# #### average revenue amount per order

# %%
df.sort_values(by=['order_id'])
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 8            4         1                       Steak Soft Tacos
# 7            4         1                          Steak Burrito
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.quantity.mode()
# Out:
# 0    1
# dtype: int64

# %% [markdown]
# #### item name with their item price

# %%
group = pd.DataFrame(df['choice_description'].groupby(df['item_name']).unique())

# %%
group.head()
# Out:
#                                                       choice_description
# item_name
# 6 Pack Soft Drink      [[Sprite], [Diet Coke], [Coke], [Nestea], [Lem...
# Barbacoa Bowl          [[Roasted Chili Corn Salsa, [Fajita Vegetables...
# Barbacoa Burrito       [[[Fresh Tomato Salsa (Mild), Tomatillo-Green ...
# Barbacoa Crispy Tacos  [[Tomatillo Red Chili Salsa, [Rice, Black Bean...
# Barbacoa Salad Bowl    [[Fresh Tomato Salsa, [Rice, Fajita Vegetables...

# %%
df = df.drop_duplicates(subset=['choice_description', 'item_name','quantity'])

# %%
df.count()
# Out:
# order_id              1949
# quantity              1949
# item_name             1949
# choice_description    1915
# item_price            1949
# dtype: int64

# %%
group = pd.DataFrame(df['item_price'].groupby(df['item_name']))

# %%
group.tail()
# Out:
#                       0                                                  1
# 45       Veggie Burrito  57      11.25
# 104      8.49
# 225     11.25
# 394 ...
# 46  Veggie Crispy Tacos      1653    8.49
# Name: item_price, dtype: float64
# 47         Veggie Salad  1694    8.49
# 2756    8.49
# 2996    8.49
# 3163   ...
# 48    Veggie Salad Bowl  186     11.25
# 295     11.25
# 455     11.25
# 496 ...
# 49    Veggie Soft Tacos  738     11.25
# 781      8.75
# 1395     8.49
# 1699...

# %% [markdown]
# ## Machine Learning Workflow
# #### Understand business problem
# #### Report
# #### Justification

# %%
df.memory_usage(index=True, deep=False)
# Out:
# Index                 97512
# order_id              15592
# quantity              15592
# item_name             15592
# choice_description    15592
# item_price            15592
# dtype: int64
